# %%
import pandas as pd

# %%
fiction_flows = pd.read_csv('/share/pierson/matt/UAIR/outputs/2026-03-05/14-48-38/ci_extraction_fiction/outputs/ci_extraction/ci_flows.csv')

# %%
fiction_flows.head()
# Out:
#    gutenberg_id  chunk_id                                       article_text  \
# 0          1342        24  “His parting obeisance”                       ...
# 1          1342        24  “His parting obeisance”                       ...
# 2          1342        25  “Mrs. Long and her nieces”                    ...
# 3          1342        25  “Mrs. Long and her nieces”                    ...
# 4          1342        26  “Why, my dear, you must know, Mrs. Long says t...
#
#    chunk_size                                  ci_reasoning_json  \
# 0        1947  {"flows": [{"original_text_snippet": "\u201cI ...
# 1        1947  {"flows": [{"original_text_snippet": "\u201cI ...
# 2        1720  {"flows": [{"original_text_snippet": "\u201cMy...
# 3        1720  {"flows": [{"original_text_snippet": "\u201cMy...
# 4        1942  {"flows": [{"original_text_snippet": "\u201cWh...
#
#    ci_reasoning_parse_error  \
# 0                       NaN
# 1                       NaN
# ...

# %%
with open('mar6_fiction_flows.json', 'w') as f:
    f.write(fiction_flows.head().to_json())

# %%
fiction_flows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5806 entries, 0 to 5805
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   gutenberg_id               5806 non-null   int64
#  1   chunk_id                   5806 non-null   int64
#  2   article_text               5806 non-null   object
#  3   chunk_size                 5806 non-null   int64
#  4   ci_reasoning_json          5806 non-null   object
#  5   ci_reasoning_parse_error   0 non-null      float64
#  6   generated_text             5806 non-null   object
#  7   has_information_exchange   5806 non-null   bool
#  8   ci_flow_count              5806 non-null   int64
#  9   article_path               0 non-null      float64
#  10  country                    0 non-null      float64
#  11  year                       0 non-null      float64
#  12  article_id                 0 non-null      float64
# ...
