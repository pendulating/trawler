# %%
import json
from xgrammar import grammar

# %%
schema = {
  "max_tokens": 1024,
  "detokenize": False,
  "guided_decoding": {
    "json": {
      "type": "object",
      "properties": {
        "deployment_domain": {
          "anyOf": [
            {
              "type": "string",
              "enum": [
                "Biometric identification and categorization of natural persons",
                "Family",
                "Romantic relationships and friendships",
                "Health and Healthcare",
                "Well-being",
                "Human-Computer Interaction",
                "Finance and Investment",
                "Education and vocational training",
                "Employment, workers management and access to self-employment",
                "Essential private services and public services and benefits",
                "Recommender Systems and Personalization",
                "Social Media",
                "Sports and Recreation",
                "Arts and Entertainment",
                "Security and Cybersecurity",
                "Marketing and Advertising",
                "Agriculture and Farming",
                "Entrepreneurship",
                "Autonomous Robots and Robotics",
                "Innovation and Research",
                "Management and Operation of critical infrastructure",
                "Law enforcement",
                "Migration, Asylum and Border control management",
                "Democracy",
                "Media and Communication",
                "Accessibility and Inclusion",
                "Energy",
                "Military and Defense",
                "Administration of justice and democratic processes",
                "Government Services and Administration",
                "Diplomacy and Foreign Policy",
                "Food Safety and Regulation",
                "Crisis Management and Emergency Response",
                "Humanitarian Aid",
                "Transport and Logistics",
                "Urban Planning",
                "Counterterrorism",
                "Environment and Sustainability",
                "International Law Enforcement and Cooperation",
                "Climate Change Mitigation and Adaptation",
                "Gaming and interactive experiences",
                "Hobbies",
                "Smart home",
                "Social and Community Services",
                "Public and private transportation",
                "Interpersonal Communication"
              ]
            },
            {
              "type": "null"
            }
          ]
        },
        "space": {
          "anyOf": [
            {
              "type": "string",
              "enum": [
                "Online space",
                "Publicly accessible space",
                "Not publicly accessible space"
              ]
            },
            {
              "type": "null"
            }
          ]
        },
        "deployment_space": {
          "anyOf": [
            {
              "type": "string",
              "enum": [
                "Online space",
                "Publicly accessible space",
                "Not publicly accessible space"
              ]
            },
            {
              "type": "null"
            }
          ]
        },
        "purpose": {
          "anyOf": [
            {
              "type": "string"
            },
            {
              "type": "null"
            }
          ]
        },
        "capability": {
          "anyOf": [
            {
              "type": "string"
            },
            {
              "type": "null"
            }
          ]
        },
        "ai_deployer": {
          "anyOf": [
            {
              "type": "string"
            },
            {
              "type": "null"
            }
          ]
        },
        "location_of_ai_deployer": {
          "anyOf": [
            {
              "type": "string"
            },
            {
              "type": "null"
            }
          ]
        },
        "ai_subject": {
          "anyOf": [
            {
              "type": "string"
            },
            {
              "type": "null"
            }
          ]
        },
        "location_of_ai_subject": {
          "anyOf": [
            {
              "type": "string"
            },
            {
              "type": "null"
            }
          ]
        },
        "ai_developer": {
          "anyOf": [
            {
              "type": "string"
            },
            {
              "type": "null"
            }
          ]
        },
        "date___time_of_event": {
          "anyOf": [
            {
              "type": "string"
            },
            {
              "type": "null"
            }
          ]
        },
        "date_and_time_of_event": {
          "anyOf": [
            {
              "type": "string"
            },
            {
              "type": "null"
            }
          ]
        },
        "list_of_harms_that_occurred": {
          "type": "array",
          "items": {
            "type": "string"
          }
        },
        "list_of_risks_that_occurred": {
          "type": "array",
          "items": {
            "type": "string"
          }
        },
        "list_of_benefits_that_occurred": {
          "type": "array",
          "items": {
            "type": "string"
          }
        },
        "missing": {
          "type": "array",
          "items": {
            "type": "string"
          }
        }
      },
      "required": [
        "missing"
      ],
      "additionalProperties": False
    }
  }
}

# %%
grammar._convert_schema_to_str(schema)
# Out:
# '{"max_tokens": 1024, "detokenize": false, "guided_decoding": {"json": {"type": "object", "properties": {"deployment_domain": {"anyOf": [{"type": "string", "enum": ["Biometric identification and categorization of natural persons", "Family", "Romantic relationships and friendships", "Health and Healthcare", "Well-being", "Human-Computer Interaction", "Finance and Investment", "Education and vocational training", "Employment, workers management and access to self-employment", "Essential private services and public services and benefits", "Recommender Systems and Personalization", "Social Media", "Sports and Recreation", "Arts and Entertainment", "Security and Cybersecurity", "Marketing and Advertising", "Agriculture and Farming", "Entrepreneurship", "Autonomous Robots and Robotics", "Innovation and Research", "Management and Operation of critical infrastructure", "Law enforcement", "Migration, Asylum and Border control management", "Democracy", "Media and Communication", "Accessibility and Inclusion", "Energy", "Military and Defense", "Administration of justice and democratic processes", "Government Services and Administration", "Diplomacy and Foreign Policy", "Food Safety and Regulation", "Crisis Management and Emergency Response", "Humanitarian Aid", "Transport and Logistics", "Urban Planning", "Counterterrorism", "Environment and Sustainability", "International Law Enforcement and Cooperation", "Climate Change Mitigation and Adaptation", "Gaming and interactive experiences", "Hobbies", "Smart home", "Social and Community Services", "Public and private transportation", "Interpersonal Communication"]}, {"type": "null"}]}, "space": {"anyOf": [{"type": "string", "enum": ["Online space", "Publicly accessible space", "Not publicly accessible space"]}, {"type": "null"}]}, "deployment_space": {"anyOf": [{"type": "string", "enum": ["Online space", "Publicly accessible space", "Not publicly accessible space"]}, {"type": "null"}]}, "purpose": {"anyOf": [{"type": "string"}, {"type": "null"}]}, "capability": {"anyOf": [{"type": "string"}, {"type": "null"}]}, "ai_deployer": {"anyOf": [{"type": "string"}, {"type": "null"}]}, "location_of_ai_deployer": {"anyOf": [{"type": "string"}, {"type": "null"}]}, "ai_subject": {"anyOf": [{"type": "string"}, {"type": "null"}]}, "location_of_ai_subject": {"anyOf": [{"type": "string"}, {"type": "null"}]}, "ai_developer": {"anyOf": [{"type": "string"}, {"type": "null"}]}, "date___time_of_event": {"anyOf": [{"type": "string"}, {"type": "null"}]}, "date_and_time_of_event": {"anyOf": [{"type": "string"}, {"type": "null"}]}, "list_of_harms_that_occurred": {"type": "array", "items": {"type": "string"}}, "list_of_risks_that_occurred": {"type": "array", "items": {"type": "string"}}, "list_of_benefits_that_occurred": {"type": "array", "items": {"type": "string"}}, "missing": {"type": "array", "items": {"type": "string"}}}, "required": ["missing"], "additionalProperties": false}}}'
