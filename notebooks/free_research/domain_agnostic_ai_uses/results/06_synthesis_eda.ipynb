# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re
from collections import Counter
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# Try to import wordcloud, with installation instructions if missing
try:
    from wordcloud import WordCloud
    WORDCLOUD_AVAILABLE = True
except ImportError:
    print('Warning: wordcloud package not found.')
    print('Install it with: pip install wordcloud')
    print('Or: conda install -c conda-forge wordcloud')
    WORDCLOUD_AVAILABLE = False

# Download required NLTK data if not already present
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt', quiet=True)

try:
    nltk.data.find('corpora/stopwords')
except LookupError:
    nltk.download('stopwords', quiet=True)

# Set up project paths
PROJECT_ROOT = Path('/share/pierson/matt/UAIR')
PAPER_PATH = PROJECT_ROOT / 'papers' / 'uair_brief' / 'figures'
PAPER_PATH.mkdir(parents=True, exist_ok=True)


RESULTS_US_PATH = '/share/pierson/matt/UAIR/outputs/2025-11-12/domain_agnostic_ai_us/full_event_pipeline_general_ai/outputs'
RESULTS_GLOBAL_PATH = '/share/pierson/matt/UAIR/outputs/2025-11-13/domain_agnostic_ai/full_event_pipeline_general_ai/outputs'

# %%
synthesis_us = pd.read_parquet(RESULTS_US_PATH + '/outputs/synthesis/synthesis_results.parquet')
