# %%
import pandas as pd

# %%
risks_and_benefits_df = pd.read_parquet("/share/pierson/matt/UAIR/outputs/classify_risks_and_benefits/classify_risks_and_benefits_results.parquet")

# %%
risks_and_benefits_df.head()
# Out:
#    _progress_row                                article_id  \
# 0              1  b51a9ba9a46ee39a4f97443288ef4cdf7594b93b
# 1              1  e90fac9854b3882830eda4bad1e693034b2acbfd
# 2              1  a69269a7d6c989d89bdfe369f3e14be1fe22986f
# 3              1  9884fb469ca54680d88875f7ebcf61aaa5fe5a6e
#
#                                         article_path  \
# 0  /share/ju/matt/sensing-ai-risks/data/global_su...
# 1  /share/ju/matt/sensing-ai-risks/data/global_su...
# 2  /share/ju/matt/sensing-ai-risks/data/global_su...
# 3  /share/ju/matt/sensing-ai-risks/data/global_su...
#
#                                         article_text  \
# 0  the google pixel 6a is reportedly unlocking ev...
# 1  photos: how does ai picture famous hungarian l...
# 2  interviews\nfeature films database\nsouthern m...
# 3  tekes invests â¬10 million into indian compan...
#
#                          batch_uuid  \
# 0  8de245ca0b6a4ccfaef60c8e448ab589
# 1  8de245ca0b6a4ccfaef60c8e448ab589
# ...

# %%
risks_and_benefits_df.to_csv("/share/pierson/matt/UAIR/outputs/classify_risks_and_benefits/classify_risks_and_benefits_results.csv", index=False)
