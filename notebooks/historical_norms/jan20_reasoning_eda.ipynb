# %%
import pandas as pd

# %%
reasoning_results = pd.read_parquet("/share/pierson/matt/UAIR/outputs/2026-01-20/11-04-03/norm_extraction/outputs/reasoning/reasoning.parquet")

# %%
reasoning_results.to_json("/share/pierson/matt/UAIR/outputs/2026-01-20/11-04-03/norm_extraction/outputs/reasoning/reasoning.json", orient="records")

# %%
reasoning_results.iloc[0:3, :].to_json("/share/pierson/matt/UAIR/outputs/2026-01-20/11-04-03/norm_extraction/outputs/reasoning/reasoning_sample.json", orient="records")
