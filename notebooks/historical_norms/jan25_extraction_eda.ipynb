# %%
import pandas as pd

# %%
extraction_results = pd.read_parquet("/share/pierson/matt/UAIR/outputs/2026-01-25/18-21-12/norm_extraction/outputs/extraction/structured_norms.parquet")

# %%
extraction_results.to_json("/share/pierson/matt/UAIR/outputs/2026-01-25/18-21-12/norm_extraction/outputs/extraction/structured_norms.json", orient="records")
