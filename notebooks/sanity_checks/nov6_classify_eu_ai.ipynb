# %%
import pandas as pd

# %%
results = pd.read_parquet("/share/pierson/matt/UAIR/outputs/classify_eu_ai_act/classify_eu_ai_act_results.parquet")

# %%
results
# Out:
#                                  article_id  \
# 0  03dfda7798e486e05faf6085a4805a677bcb1a29
# 1  31e514346592d8e416f1b939045e803139ccedbc
# 2  6504df889b8351b37e90f75f3c432232d9faf47e
# 3  d1733e6ed50cd8d56345ba1ea8d6a337c6076784
# 4  d5b39ece389a4190a7b2bb6789e672023c4476a7
# 5  7a71c743bb57e5293b51927a59e735cdde68cd15
# 6  913cfa80cfd376b9e1d6f61b32f00ba2e500150c
# 7  e55e44ce791c53e9ef848919354a6b6cd3484ccc
#
#                                         article_path  \
# 0  /share/pierson/matt/UAIR/data/us/2023/https:\\...
# 1  /share/pierson/matt/UAIR/data/us/2017/http:\\w...
# 2  /share/pierson/matt/UAIR/data/us/2020/https:\\...
# 3  /share/pierson/matt/UAIR/data/us/2023/https:\\...
# 4  /share/pierson/matt/UAIR/data/us/2020/https:\\...
# 5  /share/pierson/matt/UAIR/data/us/2022/https:\\...
# 6  /share/pierson/matt/UAIR/data/us/2023/https:\\...
# 7  /share/pierson/matt/UAIR/data/us/2021/https:\\...
#
#                                         article_text  core_tuple_verified  \
# ...

# %%
rb_results = pd.read_parquet("/share/pierson/matt/UAIR/outputs/classify_risks_and_benefits/classify_risks_and_benefits_results.parquet")

# %%
rb_results
# Out:
#                                  article_id  \
# 0  03dfda7798e486e05faf6085a4805a677bcb1a29
# 1  31e514346592d8e416f1b939045e803139ccedbc
# 2  6504df889b8351b37e90f75f3c432232d9faf47e
# 3  d1733e6ed50cd8d56345ba1ea8d6a337c6076784
# 4  d5b39ece389a4190a7b2bb6789e672023c4476a7
# 5  7a71c743bb57e5293b51927a59e735cdde68cd15
# 6  913cfa80cfd376b9e1d6f61b32f00ba2e500150c
# 7  e55e44ce791c53e9ef848919354a6b6cd3484ccc
#
#                                         article_path  \
# 0  /share/pierson/matt/UAIR/data/us/2023/https:\\...
# 1  /share/pierson/matt/UAIR/data/us/2017/http:\\w...
# 2  /share/pierson/matt/UAIR/data/us/2020/https:\\...
# 3  /share/pierson/matt/UAIR/data/us/2023/https:\\...
# 4  /share/pierson/matt/UAIR/data/us/2020/https:\\...
# 5  /share/pierson/matt/UAIR/data/us/2022/https:\\...
# 6  /share/pierson/matt/UAIR/data/us/2023/https:\\...
# 7  /share/pierson/matt/UAIR/data/us/2021/https:\\...
#
#                                         article_text  core_tuple_verified  \
# ...

# %%
rb_results.iloc[0]['rb_desc']
# Out:
# 'The AI system is intended to be used for prioritizing demining efforts in post-conflict zones by analyzing satellite imagery and sensor data to detect potential mine presence. It enables data-driven decision-making to guide humanitarian demining operations, aiming to accelerate the safe return of civilians to affected areas.'

# %%
nov6_test_rb = pd.read_parquet("/share/pierson/matt/UAIR/outputs/2025-11-06/19-06-18/full_event_pipeline/outputs/classify_risk_benefits/classify_risk_benefits_results.parquet")

# %%
nov6_test_rb['rb_desc'].values
# Out:
# array(['The AI system is designed to automate identity verification and social service delivery through biometric data analysis and predictive risk modeling, enabling faster access to public benefits and services. It integrates real-time environmental, demographic, and behavioral data to optimize resource allocation in health, education, agriculture, and urban planning, aiming to enhance equity and efficiency in public systems.'],
#       dtype=object)

# %%
nov6_test_decompose = pd.read_parquet("/share/pierson/matt/UAIR/outputs/2025-11-06/19-06-18/full_event_pipeline/outputs/decompose_nbl/tuples.parquet")

# %%
nov6_test_decompose
# Out:
#                                   article_id  \
# 0   28c8ea0d31634356536b54323f32aa1b21844248
# 1   d1d452944801d33e321d4981bcd6a60c81733e93
# 2   f1379417d761804cc4de55c8f9625ade1b33c470
# 3   06ec2f14f9997562c8b47a030f7f3e6fe8d277cd
# 4   b56766865e266d0cd8e60ab42df9c7b2ead50e79
# 5   6504df889b8351b37e90f75f3c432232d9faf47e
# 6   638db891c07e353e7ae73aa641618e75b83643be
# 7   f56281c9f3b63bc9411ca7d861ec50e2da83d132
# 8   3e4304e1e18f102a40773e82a662aebb54c59f00
# 9   e8d329893b79ce35c7ce152f79daebc11e8c4063
# 10  b0b5d11dc25bac43e1ea7a7891330013ee147481
# 11  913cfa80cfd376b9e1d6f61b32f00ba2e500150c
# 12  f61b2d6d5bcb7c5e056fed7146775858716b3d45
# 13  7a71c743bb57e5293b51927a59e735cdde68cd15
# 14  0ab17dfc70c4f7b931e9b11c4ac32a45fa712202
# 15  e4ffb64f21330bd983d68fa3d6a88b9f35e852b4
# 16  bfc31981ee054c953f30eb01f1ba9a9f991ad9fa
# 17  dc81b66ffbedb21147dac0bef78c75aa4c664be6
# 18  a9b618f711ef7b5a7ee8a701f8dd03d5e6df2691
# 19  401f7dff6323cf738d1929e3850849ade26acf46
# ...

# %%
nov6_test_verify = pd.read_parquet("/share/pierson/matt/UAIR/outputs/2025-11-06/19-06-18/full_event_pipeline/outputs/verify_nbl/verify_nbl_results.parquet")
